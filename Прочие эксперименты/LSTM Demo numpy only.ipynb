# %% [markdown]
# # Generating Text using an LSTM Network (No libraries)
#
# ## Demo
#
# We'll train an LSTM network built in pure numpy to generate Eminem lyrics. LSTMs are a fairly simple extension to neural networks, and they're behind a lot of the amazing achievements deep learning has made in the past few years.
#
# ## What is a Recurrent Network?
#
# Recurrent nets are cool, they're useful for learning sequences of data. Input. Hidden state. Output.
# ![alt text](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-rolled.png "Logo Title Text 1")
#
# It has a weight matrix that connects input to hidden state. But also a weight matrix that connects hidden state to hidden state at previous time step.
# ![alt text](https://iamtrask.github.io/img/basic_recurrence_singleton.png "Logo Title Text 1")
#
# So we could even think of it as the same feedforward network connecting to itself overtime (unrolled) since passing in
# not just input in next training iteration but input + previous hidden state
# ![alt text](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-unrolled.png "Logo Title Text 1")
#
# ## The Problem with Recurrent Networks
#
# If we want to predict the last word in the sentence "The grass is green", that's totally doable.
# ![alt text](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-shorttermdepdencies.png "Logo Title Text 1")
#
# But if we want to predict the last word in the sentence "I am French (2000 words later) i speak fluent French". We need to be able to remember long range dependencies. RNN's are bad at this. They forget the long term past easily.
# ![alt text](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-longtermdependencies.png "Logo Title Text 1")
#
# This is called the "Vanishing Gradient Problem". The Gradient exponentially decays as its backpropagated
# ![alt text](http://slideplayer.com/slide/5251503/16/images/6/Recurrent+Neural+Networks.jpg "Logo Title Text 1")
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*8JJ6sYleUtvUZR7TOyyFVg.png "Logo Title Text 1")
#
# There are two factors that affect the magnitude of gradients - the weights and the activation functions (or more precisely, their derivatives) that the gradient passes through.If either of these factors is smaller than 1, then the gradients may vanish in time; if larger than 1, then exploding might happen.
#
# But there exists a solution! Enter the LSTM Cell.
#
# ## The LSTM Cell (Long-Short Term Memory Cell)
#
# We've placed no constraints on how our model updates, so its knowledge can change pretty chaotically: at one frame it thinks the characters are in the US, at the next frame it sees the characters eating sushi and thinks they're in Japan, and at the next frame it sees polar bears and thinks they're on Hydra Island.
#
# This chaos means information quickly transforms and vanishes, and it's difficult for the model to keep a long-term memory. So what you’d like is for the network to learn how to update its beliefs (scenes without Bob shouldn't change Bob-related information, scenes with Alice should focus on gathering details about her), in a way that its knowledge of the world evolves more gently.
#
# It replaces the normal RNN cell and uses an input, forget, and output gate. As well as a cell state
# ![alt text](https://www.researchgate.net/profile/Mohsen_Fayyaz/publication/306377072/figure/fig2/AS:398082849165314@1471921755580/Fig-2-An-example-of-a-basic-LSTM-cell-left-and-a-basic-RNN-cell-right-Figure.ppm "Logo Title Text 1")
#
# ![alt text](https://kijungyoon.github.io/assets/images/lstm.png "Logo Title Text 1")
# These gates each have their own set of weight values. The whole thing is differentiable (meaning we compute gradients and update the weights using them) so we can backprop through it
#
# We want our model to be able to know what to forget, what to remember. So when new a input comes in, the model first forgets any long-term information it decides it no longer needs. Then it learns which parts of the new input are worth using, and saves them into its long-term memory.
#
# And instead of using the full long-term memory all the time, it learns which parts to focus on instead.
#
# Basically, we need mechanisms for forgetting, remembering, and attention. That's what the LSTM cell provides us.
#
# Whereas a vanilla RNN uses one equation to update its hidden state/memory:
# ![alt text](http://i.imgur.com/nT4VBPf.png "Logo Title Text 1")
#
# Which piece of long term memory to remember and forget?
# We'll use new input and working memory to learn remember gate.
# Which part of new data should we use and save?
# Update working memory using attention vector.
#
# - The long-term memory, is usually called the cell state,
# - The working memory, is usually called the hidden state. This is analogous to the hidden state in vanilla RNNs.
# - The remember vector, is usually called the forget gate (despite the fact that a 1 in the forget gate still means to keep the memory and a 0 still means to forget it),
# - The save vector, is usually called the input gate (as it determines how much of the input to let into the cell state),
# - The focus vector, is usually called the output gate )
#
# ## Use cases
#
#
# Video
# [![IMAGE ALT TEXT HERE](http://img.youtube.com/vi/mLxsbWAYIpw/0.jpg)](https://www.youtube.com/watch?time_continue=14&v=mLxsbWAYIpw)
#
# The most popular application right now is actually in natural language processing
# which involves sequential data such as words,  sentences, sound spectrogram, etc. So applications with translation,  sentiment analysis,  text generation, etc.
#
# In other less obvious areas there's also applications of lstm.  Such as for image classification (feeding each picture's pixel in row by row). And even for deepmind's deep Q Learning agents.
#
# ## Other great examples
#
# Speech recognition Tensorflow - https://github.com/zzw922cn/Automatic_Speech_Recognition
# LSTM visualization - https://github.com/HendrikStrobelt/LSTMVis

# %% [markdown]
# ### Steps
#
# 1. Build RNN class
# 2. Build LSTM Cell Class
# 3. Data Loading Functions
# 3. Training time!
#
# ![alt text](http://eric-yuan.me/wp-content/uploads/2015/06/5.jpg "Logo Title Text 1")

# %%
import numpy as np

class RecurrentNeuralNetwork:
    #input (word), expected output (next word), num of words (num of recurrences), array expected outputs, learning rate
    def __init__ (self, xs, ys, rl, eo, lr):
        #initial input (first word)
        self.x = np.zeros(xs)
        #input size 
        self.xs = xs
        #expected output (next word)
        self.y = np.zeros(ys)
        #output size
        self.ys = ys
        #weight matrix for interpreting results from LSTM cell (num words x num words matrix)
        self.w = np.random.random((ys, ys))
        #matrix used in RMSprop
        self.G = np.zeros_like(self.w)
        #length of the recurrent network - number of recurrences i.e num of words
        self.rl = rl
        #learning rate 
        self.lr = lr
        #array for storing inputs
        self.ia = np.zeros((rl+1,xs))
        #array for storing cell states
        self.ca = np.zeros((rl+1,ys))
        #array for storing outputs
        self.oa = np.zeros((rl+1,ys))
        #array for storing hidden states
        self.ha = np.zeros((rl+1,ys))
        #forget gate 
        self.af = np.zeros((rl+1,ys))
        #input gate
        self.ai = np.zeros((rl+1,ys))
        #cell state
        self.ac = np.zeros((rl+1,ys))
        #output gate
        self.ao = np.zeros((rl+1,ys))
        #array of expected output values
        self.eo = np.vstack((np.zeros(eo.shape[0]), eo.T))
        #declare LSTM cell (input, output, amount of recurrence, learning rate)
        self.LSTM = LSTM(xs, ys, rl, lr)
    
    #activation function. simple nonlinearity, convert nums into probabilities between 0 and 1
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    #the derivative of the sigmoid function. used to compute gradients for backpropagation
    def dsigmoid(self, x):
        return self.sigmoid(x) * (1 - self.sigmoid(x))    
    
    #lets apply a series of matrix operations to our input (curr word) to compute a predicted output (next word)
    def forwardProp(self):
        for i in range(1, self.rl+1):
            self.LSTM.x = np.hstack((self.ha[i-1], self.x))
            cs, hs, f, inp, c, o = self.LSTM.forwardProp()
            #store computed cell state
            self.ca[i] = cs
            self.ha[i] = hs
            self.af[i] = f
            self.ai[i] = inp
            self.ac[i] = c
            self.ao[i] = o
            self.oa[i] = self.sigmoid(np.dot(self.w, hs))
            self.x = self.eo[i-1]
        return self.oa
   
    
    def backProp(self):
        #update our weight matrices (Both in our Recurrent network, as well as the weight matrices inside LSTM cell)
        #init an empty error value 
        totalError = 0
        #initialize matrices for gradient updates
        #First, these are RNN level gradients
        #cell state
        dfcs = np.zeros(self.ys)
        #hidden state,
        dfhs = np.zeros(self.ys)
        #weight matrix
        tu = np.zeros((self.ys,self.ys))
        #Next, these are LSTM level gradients
        #forget gate
        tfu = np.zeros((self.ys, self.xs+self.ys))
        #input gate
        tiu = np.zeros((self.ys, self.xs+self.ys))
        #cell unit
        tcu = np.zeros((self.ys, self.xs+self.ys))
        #output gate
        tou = np.zeros((self.ys, self.xs+self.ys))
        #loop backwards through recurrences
        for i in range(self.rl, -1, -1):
            #error = calculatedOutput - expectedOutput
            error = self.oa[i] - self.eo[i]
            #calculate update for weight matrix
            #(error * derivative of the output) * hidden state
            tu += np.dot(np.atleast_2d(error * self.dsigmoid(self.oa[i])), np.atleast_2d(self.ha[i]).T)
            #Time to propagate error back to exit of LSTM cell
            #1. error * RNN weight matrix
            error = np.dot(error, self.w)
            #2. set input values of LSTM cell for recurrence i (horizontal stack of arrays, hidden + input)
            self.LSTM.x = np.hstack((self.ha[i-1], self.ia[i]))
            #3. set cell state of LSTM cell for recurrence i (pre-updates)
            self.LSTM.cs = self.ca[i]
            #Finally, call the LSTM cell's backprop, retreive gradient updates
            #gradient updates for forget, input, cell unit, and output gates + cell states & hiddens states
            fu, iu, cu, ou, dfcs, dfhs = self.LSTM.backProp(error, self.ca[i-1], self.af[i], self.ai[i], self.ac[i], self.ao[i], dfcs, dfhs)
            #calculate total error (not necesarry, used to measure training progress)
            totalError += np.sum(error)
            #accumulate all gradient updates
            #forget gate
            tfu += fu
            #input gate
            tiu += iu
            #cell state
            tcu += cu
            #output gate
            tou += ou
        #update LSTM matrices with average of accumulated gradient updates    
        self.LSTM.update(tfu/self.rl, tiu/self.rl, tcu/self.rl, tou/self.rl) 
        #update weight matrix with average of accumulated gradient updates  
        self.update(tu/self.rl)
        #return total error of this iteration
        return totalError
    
    def update(self, u):
        #vanilla implementation of RMSprop
        self.G = 0.9 * self.G + 0.1 * u**2  
        self.w -= self.lr/np.sqrt(self.G + 1e-8) * u
        return
    
    #this is where we generate some sample text after having fully trained our model
    #i.e error is below some threshold
    def sample(self):
         #loop through recurrences - start at 1 so the 0th entry of all arrays will be an array of 0's
        for i in range(1, self.rl+1):
            #set input for LSTM cell, combination of input (previous output) and previous hidden state
            self.LSTM.x = np.hstack((self.ha[i-1], self.x))
            #run forward prop on the LSTM cell, retrieve cell state and hidden state
            cs, hs, f, inp, c, o = self.LSTM.forwardProp()
            #store input as vector
            maxI = np.argmax(self.x)
            self.x = np.zeros_like(self.x)
            self.x[maxI] = 1
            self.ia[i] = self.x #Use np.argmax?
            #store cell states
            self.ca[i] = cs
            #store hidden state
            self.ha[i] = hs
            #forget gate
            self.af[i] = f
            #input gate
            self.ai[i] = inp
            #cell state
            self.ac[i] = c
            #output gate
            self.ao[i] = o
            #calculate output by multiplying hidden state with weight matrix
            self.oa[i] = self.sigmoid(np.dot(self.w, hs))
            #compute new input
            maxI = np.argmax(self.oa[i])
            newX = np.zeros_like(self.x)
            newX[maxI] = 1
            self.x = newX
        #return all outputs    
        return self.oa

# %% [markdown]
# ![alt text](http://i.imgur.com/BUAVEZg.png "Logo Title Text 1")

# %%
class LSTM:
    # LSTM cell (input, output, amount of recurrence, learning rate)
    def __init__ (self, xs, ys, rl, lr):
        #input is word length x word length
        self.x = np.zeros(xs+ys)
        #input size is word length + word length
        self.xs = xs + ys
        #output 
        self.y = np.zeros(ys)
        #output size
        self.ys = ys
        #cell state intialized as size of prediction
        self.cs = np.zeros(ys)
        #how often to perform recurrence
        self.rl = rl
        #balance the rate of training (learning rate)
        self.lr = lr
        #init weight matrices for our gates
        #forget gate
        self.f = np.random.random((ys, xs+ys))
        #input gate
        self.i = np.random.random((ys, xs+ys))
        #cell state
        self.c = np.random.random((ys, xs+ys))
        #output gate
        self.o = np.random.random((ys, xs+ys))
        #forget gate gradient
        self.Gf = np.zeros_like(self.f)
        #input gate gradient
        self.Gi = np.zeros_like(self.i)
        #cell state gradient
        self.Gc = np.zeros_like(self.c)
        #output gate gradient
        self.Go = np.zeros_like(self.o)
    
    #activation function to activate our forward prop, just like in any type of neural network
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    #derivative of sigmoid to help computes gradients
    def dsigmoid(self, x):
        return self.sigmoid(x) * (1 - self.sigmoid(x))
    
    #tanh! another activation function, often used in LSTM cells
    #Having stronger gradients: since data is centered around 0, 
    #the derivatives are higher. To see this, calculate the derivative 
    #of the tanh function and notice that input values are in the range [0,1].
    def tangent(self, x):
        return np.tanh(x)
    
    #derivative for computing gradients
    def dtangent(self, x):
        return 1 - np.tanh(x)**2
    
    #lets compute a series of matrix multiplications to convert our input into our output
    def forwardProp(self):
        f = self.sigmoid(np.dot(self.f, self.x))
        self.cs *= f
        i = self.sigmoid(np.dot(self.i, self.x))
        c = self.tangent(np.dot(self.c, self.x))
        self.cs += i * c
        o = self.sigmoid(np.dot(self.o, self.x))
        self.y = o * self.tangent(self.cs)
        return self.cs, self.y, f, i, c, o
    
   
    def backProp(self, e, pcs, f, i, c, o, dfcs, dfhs):
        #error = error + hidden state derivative. clip the value between -6 and 6.
        e = np.clip(e + dfhs, -6, 6)
        #multiply error by activated cell state to compute output derivative
        do = self.tangent(self.cs) * e
        #output update = (output deriv * activated output) * input
        ou = np.dot(np.atleast_2d(do * self.dtangent(o)).T, np.atleast_2d(self.x))
        #derivative of cell state = error * output * deriv of cell state + deriv cell
        dcs = np.clip(e * o * self.dtangent(self.cs) + dfcs, -6, 6)
        #deriv of cell = deriv cell state * input
        dc = dcs * i
        #cell update = deriv cell * activated cell * input
        cu = np.dot(np.atleast_2d(dc * self.dtangent(c)).T, np.atleast_2d(self.x))
        #deriv of input = deriv cell state * cell
        di = dcs * c
        #input update = (deriv input * activated input) * input
        iu = np.dot(np.atleast_2d(di * self.dsigmoid(i)).T, np.atleast_2d(self.x))
        #deriv forget = deriv cell state * all cell states
        df = dcs * pcs
        #forget update = (deriv forget * deriv forget) * input
        fu = np.dot(np.atleast_2d(df * self.dsigmoid(f)).T, np.atleast_2d(self.x))
        #deriv cell state = deriv cell state * forget
        dpcs = dcs * f
        #deriv hidden state = (deriv cell * cell) * output + deriv output * output * output deriv input * input * output + deriv forget
        #* forget * output
        dphs = np.dot(dc, self.c)[:self.ys] + np.dot(do, self.o)[:self.ys] + np.dot(di, self.i)[:self.ys] + np.dot(df, self.f)[:self.ys] 
        #return update gradinets for forget, input, cell, output, cell state, hidden state
        return fu, iu, cu, ou, dpcs, dphs
            
    def update(self, fu, iu, cu, ou):
        #update forget, input, cell, and output gradients
        self.Gf = 0.9 * self.Gf + 0.1 * fu**2 
        self.Gi = 0.9 * self.Gi + 0.1 * iu**2   
        self.Gc = 0.9 * self.Gc + 0.1 * cu**2   
        self.Go = 0.9 * self.Go + 0.1 * ou**2   
        
        #update our gates using our gradients
        self.f -= self.lr/np.sqrt(self.Gf + 1e-8) * fu
        self.i -= self.lr/np.sqrt(self.Gi + 1e-8) * iu
        self.c -= self.lr/np.sqrt(self.Gc + 1e-8) * cu
        self.o -= self.lr/np.sqrt(self.Go + 1e-8) * ou
        return

# %%
def LoadText():
    #open text and return input and output data (series of words)
    with open("eminem.txt", "r") as text_file:
        data = text_file.read()
    text = list(data)
    outputSize = len(text)
    data = list(set(text))
    uniqueWords, dataSize = len(data), len(data) 
    returnData = np.zeros((uniqueWords, dataSize))
    for i in range(0, dataSize):
        returnData[i][i] = 1
    returnData = np.append(returnData, np.atleast_2d(data), axis=0)
    output = np.zeros((uniqueWords, outputSize))
    for i in range(0, outputSize):
        index = np.where(np.asarray(data) == text[i])
        output[:,i] = returnData[0:-1,index[0]].astype(float).ravel()  
    return returnData, uniqueWords, output, outputSize, data

#write the predicted output (series of words) to disk
def ExportText(output, data):
    finalOutput = np.zeros_like(output)
    prob = np.zeros_like(output[0])
    outputText = ""
    print(len(data))
    print(output.shape[0])
    for i in range(0, output.shape[0]):
        for j in range(0, output.shape[1]):
            prob[j] = output[i][j] / np.sum(output[i])
        outputText += np.random.choice(data, p=prob)    
    with open("output.txt", "w") as text_file:
        text_file.write(outputText)
    return

# %%
#Begin program    
print("Beginning")
iterations = 5000
learningRate = 0.001
#load input output data (words)
returnData, numCategories, expectedOutput, outputSize, data = LoadText()
print("Done Reading")
#init our RNN using our hyperparams and dataset
RNN = RecurrentNeuralNetwork(numCategories, numCategories, outputSize, expectedOutput, learningRate)

#training time!
for i in range(1, iterations):
    #compute predicted next word
    RNN.forwardProp()
    #update all our weights using our error
    error = RNN.backProp()
    #once our error/loss is small enough
    print("Error on iteration ", i, ": ", error)
    if error > -100 and error < 100 or i % 100 == 0:
        #we can finally define a seed word
        seed = np.zeros_like(RNN.x)
        maxI = np.argmax(np.random.random(RNN.x.shape))
        seed[maxI] = 1
        RNN.x = seed  
        #and predict some new text!
        output = RNN.sample()
        print(output)    
        #write it all to disk
        ExportText(output, data)
        print("Done Writing")
print("Complete")
# Out:
# Beginning
# Done Reading
# Error on iteration  1 :  19722098.007
# Error on iteration  2 :  19598943.3085
# Error on iteration  3 :  19508297.3134
# Error on iteration  4 :  19432387.2263
# Error on iteration  5 :  19365003.2324
# Error on iteration  6 :  19303253.6747
# Error on iteration  7 :  19245526.6041
# Error on iteration  8 :  19190819.1112
# Error on iteration  9 :  19138459.4497
# Error on iteration  10 :  19087973.1918
# Error on iteration  11 :  19039011.6275
# Error on iteration  12 :  18991310.3641
# Error on iteration  13 :  18944663.9044
# Error on iteration  14 :  18898909.2682
# Error on iteration  15 :  18853915.0176
# Error on iteration  16 :  18809573.6584
# Error on iteration  17 :  18765796.2301
# Error on iteration  18 :  18722508.3622
# Error on iteration  19 :  18679647.3379
# Error on iteration  20 :  18637159.8685
# Error on iteration  21 :  18595000.3789
# Error on iteration  22 :  18553129.6676
# Error on iteration  23 :  18511513.8459
# Error on iteration  24 :  18470123.4888
# Error on iteration  25 :  18428932.9475
# Error on iteration  26 :  18387919.7878
# Error on iteration  27 :  18347064.3277
# Error on iteration  28 :  18306349.2525
# Error on iteration  29 :  18265759.2944
# Error on iteration  30 :  18225280.961
# Error on iteration  31 :  18184902.3062
# Error on iteration  32 :  18144612.7355
# Error on iteration  33 :  18104402.8384
# Error on iteration  34 :  18064264.2449
# Error on iteration  35 :  18024189.5012
# Error on iteration  36 :  17984171.9627
# Error on iteration  37 :  17944205.7
# Error on iteration  38 :  17904285.4173
# Error on iteration  39 :  17864406.3812
# Error on iteration  40 :  17824564.358
# Error on iteration  41 :  17784755.5584
# Error on iteration  42 :  17744976.5891
# Error on iteration  43 :  17705224.4099
# Error on iteration  44 :  17665496.2953
# Error on iteration  45 :  17625789.8018
# Error on iteration  46 :  17586102.737
# Error on iteration  47 :  17546433.1338
# Error on iteration  48 :  17506779.2261
# Error on iteration  49 :  17467139.4287
# Error on iteration  50 :  17427512.3175
# Error on iteration  51 :  17387896.6136
# Error on iteration  52 :  17348291.1678
# Error on iteration  53 :  17308694.9474
# Error on iteration  54 :  17269107.0245
# Error on iteration  55 :  17229526.5648
# Error on iteration  56 :  17189952.8185
# Error on iteration  57 :  17150385.1111
# Error on iteration  58 :  17110822.8366
# Error on iteration  59 :  17071265.4496
# Error on iteration  60 :  17031712.4599
# Error on iteration  61 :  16992163.4265
# Error on iteration  62 :  16952617.9527
# Error on iteration  63 :  16913075.6818
# Error on iteration  64 :  16873536.2929
# Error on iteration  65 :  16833999.4971
# Error on iteration  66 :  16794465.0347
# Error on iteration  67 :  16754932.6721
# Error on iteration  68 :  16715402.1989
# Error on iteration  69 :  16675873.4261
# Error on iteration  70 :  16636346.1833
# Error on iteration  71 :  16596820.3174
# Error on iteration  72 :  16557295.6906
# Error on iteration  73 :  16517772.1789
# Error on iteration  74 :  16478249.6707
# Error on iteration  75 :  16438728.0656
# Error on iteration  76 :  16399207.2732
# Error on iteration  77 :  16359687.2122
# Error on iteration  78 :  16320167.8095
# Error on iteration  79 :  16280648.9991
# Error on iteration  80 :  16241130.7219
# Error on iteration  81 :  16201612.9244
# Error on iteration  82 :  16162095.5587
# Error on iteration  83 :  16122578.5816
# Error on iteration  84 :  16083061.9542
# Error on iteration  85 :  16043545.6416
# Error on iteration  86 :  16004029.6123
# Error on iteration  87 :  15964513.8378
# Error on iteration  88 :  15924998.2928
# Error on iteration  89 :  15885482.9543
# Error on iteration  90 :  15845967.8016
# Error on iteration  91 :  15806452.8162
# Error on iteration  92 :  15766937.9813
# Error on iteration  93 :  15727423.2818
# Error on iteration  94 :  15687908.7043
# Error on iteration  95 :  15648394.2364
# Error on iteration  96 :  15608879.8673
# Error on iteration  97 :  15569365.5871
# Error on iteration  98 :  15529851.3868
# Error on iteration  99 :  15490337.2585
# Error on iteration  100 :  15450823.195
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.99999865  0.99999721  0.9999901  ...,  0.99999985  0.99999783
#    0.9999999 ]
#  [ 1.          1.          0.99999999 ...,  1.          1.          1.        ]
#  ...,
#  [ 1.          1.          0.99999999 ...,  1.          1.          1.        ]
#  [ 1.          1.          0.99999999 ...,  1.          1.          1.        ]
#  [ 1.          1.          0.99999999 ...,  1.          1.          1.        ]]
# 60
# 11163
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in double_scalars
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in less
# Done Writing
# Error on iteration  101 :  15411309.1897
# Error on iteration  102 :  15371795.245
# Error on iteration  103 :  15332281.3386
# Error on iteration  104 :  15292767.4749
# Error on iteration  105 :  15253253.6494
# Error on iteration  106 :  15213739.8584
# Error on iteration  107 :  15174226.0984
# Error on iteration  108 :  15134712.3663
# Error on iteration  109 :  15095198.6593
# Error on iteration  110 :  15055684.975
# Error on iteration  111 :  15016171.3109
# Error on iteration  112 :  14976657.6652
# Error on iteration  113 :  14937144.0359
# Error on iteration  114 :  14897630.4214
# Error on iteration  115 :  14858116.8203
# Error on iteration  116 :  14818603.2311
# Error on iteration  117 :  14779089.6527
# Error on iteration  118 :  14739576.0839
# Error on iteration  119 :  14700062.5239
# Error on iteration  120 :  14660548.9718
# Error on iteration  121 :  14621035.4266
# Error on iteration  122 :  14581521.8878
# Error on iteration  123 :  14542008.3546
# Error on iteration  124 :  14502494.8266
# Error on iteration  125 :  14462981.3031
# Error on iteration  126 :  14423467.7838
# Error on iteration  127 :  14383954.2681
# Error on iteration  128 :  14344440.7557
# Error on iteration  129 :  14304927.2463
# Error on iteration  130 :  14265413.7396
# Error on iteration  131 :  14225900.2352
# Error on iteration  132 :  14186386.7329
# Error on iteration  133 :  14146873.2324
# Error on iteration  134 :  14107359.7337
# Error on iteration  135 :  14067846.2364
# Error on iteration  136 :  14028332.7405
# Error on iteration  137 :  13988819.2457
# Error on iteration  138 :  13949305.7519
# Error on iteration  139 :  13909792.259
# Error on iteration  140 :  13870278.7669
# Error on iteration  141 :  13830765.2754
# Error on iteration  142 :  13791251.7845
# Error on iteration  143 :  13751738.2941
# Error on iteration  144 :  13712224.8041
# Error on iteration  145 :  13672711.3144
# Error on iteration  146 :  13633197.825
# Error on iteration  147 :  13593684.3357
# Error on iteration  148 :  13554170.8466
# Error on iteration  149 :  13514657.3575
# Error on iteration  150 :  13475143.8685
# Error on iteration  151 :  13435630.3793
# Error on iteration  152 :  13396116.8901
# Error on iteration  153 :  13356603.4008
# Error on iteration  154 :  13317089.9113
# Error on iteration  155 :  13277576.4215
# Error on iteration  156 :  13238062.9315
# Error on iteration  157 :  13198549.4411
# Error on iteration  158 :  13159035.9504
# Error on iteration  159 :  13119522.4593
# Error on iteration  160 :  13080008.9677
# Error on iteration  161 :  13040495.4756
# Error on iteration  162 :  13000981.983
# Error on iteration  163 :  12961468.4898
# Error on iteration  164 :  12921954.996
# Error on iteration  165 :  12882441.5015
# Error on iteration  166 :  12842928.0062
# Error on iteration  167 :  12803414.5102
# Error on iteration  168 :  12763901.0134
# Error on iteration  169 :  12724387.5156
# Error on iteration  170 :  12684874.017
# Error on iteration  171 :  12645360.5173
# Error on iteration  172 :  12605847.0165
# Error on iteration  173 :  12566333.5146
# Error on iteration  174 :  12526820.0116
# Error on iteration  175 :  12487306.5072
# Error on iteration  176 :  12447793.0015
# Error on iteration  177 :  12408279.4943
# Error on iteration  178 :  12368765.9857
# Error on iteration  179 :  12329252.4754
# Error on iteration  180 :  12289738.9635
# Error on iteration  181 :  12250225.4497
# Error on iteration  182 :  12210711.934
# Error on iteration  183 :  12171198.4164
# Error on iteration  184 :  12131684.8966
# Error on iteration  185 :  12092171.3746
# Error on iteration  186 :  12052657.8502
# Error on iteration  187 :  12013144.3232
# Error on iteration  188 :  11973630.7937
# Error on iteration  189 :  11934117.2613
# Error on iteration  190 :  11894603.726
# Error on iteration  191 :  11855090.1875
# Error on iteration  192 :  11815576.6457
# Error on iteration  193 :  11776063.1005
# Error on iteration  194 :  11736549.5515
# Error on iteration  195 :  11697035.9986
# Error on iteration  196 :  11657522.4416
# Error on iteration  197 :  11618008.8803
# Error on iteration  198 :  11578495.3144
# Error on iteration  199 :  11538981.7436
# Error on iteration  200 :  11499468.1676
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.9999646   0.99994013  0.99960196 ...,  0.99999647  0.99991779
#    0.99999777]
#  [ 0.99999993  0.9999998   0.99999772 ...,  1.          0.99999981  1.        ]
#  ...,
#  [ 0.99999993  0.9999998   0.99999772 ...,  1.          0.99999981  1.        ]
#  [ 0.99999993  0.9999998   0.99999772 ...,  1.          0.99999981  1.        ]
#  [ 0.99999993  0.9999998   0.99999772 ...,  1.          0.99999981  1.        ]]
# 60
# 11163
# Done Writing
# Error on iteration  201 :  11459954.5611
# Error on iteration  202 :  11420441.0887
# Error on iteration  203 :  11380927.4866
# Error on iteration  204 :  11341413.879
# Error on iteration  205 :  11301900.2655
# Error on iteration  206 :  11262386.6455
# Error on iteration  207 :  11222873.0187
# Error on iteration  208 :  11183359.3845
# Error on iteration  209 :  11143845.7425
# Error on iteration  210 :  11104332.092
# Error on iteration  211 :  11064818.4326
# Error on iteration  212 :  11025304.7637
# Error on iteration  213 :  10985791.0847
# Error on iteration  214 :  10946277.395
# Error on iteration  215 :  10906763.6939
# Error on iteration  216 :  10867249.9808
# Error on iteration  217 :  10827736.2549
# Error on iteration  218 :  10788222.5155
# Error on iteration  219 :  10748708.7619
# Error on iteration  220 :  10709194.9931
# Error on iteration  221 :  10669681.2083
# Error on iteration  222 :  10630167.4066
# Error on iteration  223 :  10590653.587
# Error on iteration  224 :  10551139.7486
# Error on iteration  225 :  10511625.8903
# Error on iteration  226 :  10472112.0108
# Error on iteration  227 :  10432598.1092
# Error on iteration  228 :  10393084.184
# Error on iteration  229 :  10353570.234
# Error on iteration  230 :  10314056.2578
# Error on iteration  231 :  10274542.254
# Error on iteration  232 :  10235028.221
# Error on iteration  233 :  10195514.1571
# Error on iteration  234 :  10156000.0608
# Error on iteration  235 :  10116485.9301
# Error on iteration  236 :  10076971.7631
# Error on iteration  237 :  10037457.5579
# Error on iteration  238 :  9997943.3124
# Error on iteration  239 :  9958429.02429
# Error on iteration  240 :  9918914.69125
# Error on iteration  241 :  9879400.3108
# Error on iteration  242 :  9839885.88034
# Error on iteration  243 :  9800371.39712
# Error on iteration  244 :  9760856.85823
# Error on iteration  245 :  9721342.26062
# Error on iteration  246 :  9681827.60108
# Error on iteration  247 :  9642312.8762
# Error on iteration  248 :  9602798.08241
# Error on iteration  249 :  9563283.21594
# Error on iteration  250 :  9523768.27282
# Error on iteration  251 :  9484253.24886
# Error on iteration  252 :  9444738.13965
# Error on iteration  253 :  9405222.94055
# Error on iteration  254 :  9365707.64666
# Error on iteration  255 :  9326192.25282
# Error on iteration  256 :  9286676.75361
# Error on iteration  257 :  9247161.14329
# Error on iteration  258 :  9207645.41585
# Error on iteration  259 :  9168129.56494
# Error on iteration  260 :  9128613.58386
# Error on iteration  261 :  9089097.46559
# Error on iteration  262 :  9049581.20271
# Error on iteration  263 :  9010064.78742
# Error on iteration  264 :  8970548.21149
# Error on iteration  265 :  8931031.46628
# Error on iteration  266 :  8891514.54268
# Error on iteration  267 :  8851997.43111
# Error on iteration  268 :  8812480.12147
# Error on iteration  269 :  8772962.60315
# Error on iteration  270 :  8733444.86497
# Error on iteration  271 :  8693926.89517
# Error on iteration  272 :  8654408.68139
# Error on iteration  273 :  8614890.21059
# Error on iteration  274 :  8575371.46909
# Error on iteration  275 :  8535852.44249
# Error on iteration  276 :  8496333.11561
# Error on iteration  277 :  8456813.47254
# Error on iteration  278 :  8417293.4965
# Error on iteration  279 :  8377773.16988
# Error on iteration  280 :  8338252.47414
# Error on iteration  281 :  8298731.38979
# Error on iteration  282 :  8259209.89637
# Error on iteration  283 :  8219687.97232
# Error on iteration  284 :  8180165.59504
# Error on iteration  285 :  8140642.74074
# Error on iteration  286 :  8101119.38443
# Error on iteration  287 :  8061595.49985
# Error on iteration  288 :  8022071.05943
# Error on iteration  289 :  7982546.03419
# Error on iteration  290 :  7943020.3937
# Error on iteration  291 :  7903494.106
# Error on iteration  292 :  7863967.13754
# Error on iteration  293 :  7824439.45308
# Error on iteration  294 :  7784911.01563
# Error on iteration  295 :  7745381.78637
# Error on iteration  296 :  7705851.72455
# Error on iteration  297 :  7666320.78743
# Error on iteration  298 :  7626788.93013
# Error on iteration  299 :  7587256.1056
# Error on iteration  300 :  7547722.26449
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.99830879  0.99654571  0.98749424 ...,  0.99984429  0.99688917
#    0.99986024]
#  [ 0.999973    0.9999166   0.99906747 ...,  0.9999993   0.99992306
#    0.99999959]
#  ...,
#  [ 0.99997354  0.99991758  0.99908083 ...,  0.99999931  0.99992466
#    0.9999996 ]
#  [ 0.99997354  0.99991758  0.99908083 ...,  0.99999931  0.99992466
#    0.9999996 ]
#  [ 0.99997354  0.99991758  0.99908083 ...,  0.99999931  0.99992466
#    0.9999996 ]]
# 60
# 11163
# Done Writing
# Error on iteration  301 :  7508186.64531
# Error on iteration  302 :  7468651.49365
# Error on iteration  303 :  7429114.26493
# Error on iteration  304 :  7389575.79872
# Error on iteration  305 :  7350036.03234
# Error on iteration  306 :  7310494.90013
# Error on iteration  307 :  7270952.33334
# Error on iteration  308 :  7231408.25997
# Error on iteration  309 :  7191862.60465
# Error on iteration  310 :  7152315.28848
# Error on iteration  311 :  7112766.22888
# Error on iteration  312 :  7073215.33944
# Error on iteration  313 :  7033662.52975
# Error on iteration  314 :  6994107.70527
# Error on iteration  315 :  6954550.76712
# Error on iteration  316 :  6914991.61193
# Error on iteration  317 :  6875430.13165
# Error on iteration  318 :  6835866.21338
# Error on iteration  319 :  6796299.73919
# Error on iteration  320 :  6756730.58588
# Error on iteration  321 :  6717158.62487
# Error on iteration  322 :  6677583.72192
# Error on iteration  323 :  6638005.73697
# Error on iteration  324 :  6598424.52394
# Error on iteration  325 :  6558839.9305
# Error on iteration  326 :  6519251.79788
# Error on iteration  327 :  6479659.96066
# Error on iteration  328 :  6440064.24652
# Error on iteration  329 :  6400464.4761
# Error on iteration  330 :  6360860.46272
# Error on iteration  331 :  6321252.01223
# Error on iteration  332 :  6281638.92275
# Error on iteration  333 :  6242020.98452
# Error on iteration  334 :  6202397.97967
# Error on iteration  335 :  6162769.68204
# Error on iteration  336 :  6123135.857
# Error on iteration  337 :  6083496.26131
# Error on iteration  338 :  6043850.64292
# Error on iteration  339 :  6004198.74085
# Error on iteration  340 :  5964540.28508
# Error on iteration  341 :  5924874.99641
# Error on iteration  342 :  5885202.58644
# Error on iteration  343 :  5845522.75748
# Error on iteration  344 :  5805835.20252
# Error on iteration  345 :  5766139.60528
# Error on iteration  346 :  5726435.64025
# Error on iteration  347 :  5686722.97279
# Error on iteration  348 :  5647001.25928
# Error on iteration  349 :  5607270.14732
# Error on iteration  350 :  5567529.276
# Error on iteration  351 :  5527778.27627
# Error on iteration  352 :  5488016.77128
# Error on iteration  353 :  5448244.37694
# Error on iteration  354 :  5408460.7025
# Error on iteration  355 :  5368665.35121
# Error on iteration  356 :  5328857.92115
# Error on iteration  357 :  5289038.00612
# Error on iteration  358 :  5249205.19674
# Error on iteration  359 :  5209359.08161
# Error on iteration  360 :  5169499.24868
# Error on iteration  361 :  5129625.28678
# Error on iteration  362 :  5089736.78729
# Error on iteration  363 :  5049833.34608
# Error on iteration  364 :  5009914.56559
# Error on iteration  365 :  4969980.05718
# Error on iteration  366 :  4930029.4437
# Error on iteration  367 :  4890062.3623
# Error on iteration  368 :  4850078.46752
# Error on iteration  369 :  4810077.43472
# Error on iteration  370 :  4770058.96366
# Error on iteration  371 :  4730022.78258
# Error on iteration  372 :  4689968.65242
# Error on iteration  373 :  4649896.37151
# Error on iteration  374 :  4609805.78054
# Error on iteration  375 :  4569696.76787
# Error on iteration  376 :  4529569.27518
# Error on iteration  377 :  4489423.30358
# Error on iteration  378 :  4449258.91987
# Error on iteration  379 :  4409076.26335
# Error on iteration  380 :  4368875.55278
# Error on iteration  381 :  4328657.09376
# Error on iteration  382 :  4288421.28631
# Error on iteration  383 :  4248168.63275
# Error on iteration  384 :  4207899.74573
# Error on iteration  385 :  4167615.35645
# Error on iteration  386 :  4127316.32293
# Error on iteration  387 :  4087003.63831
# Error on iteration  388 :  4046678.43911
# Error on iteration  389 :  4006342.01325
# Error on iteration  390 :  3965995.80792
# Error on iteration  391 :  3925641.43695
# Error on iteration  392 :  3885280.6878
# Error on iteration  393 :  3844915.52778
# Error on iteration  394 :  3804548.10959
# Error on iteration  395 :  3764180.77582
# Error on iteration  396 :  3723816.06243
# Error on iteration  397 :  3683456.70082
# Error on iteration  398 :  3643105.61859
# Error on iteration  399 :  3602765.93849
# Error on iteration  400 :  3562440.97571
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.9548731   0.88414924  0.68469685 ...,  0.99285281  0.90887959
#    0.99541616]
#  [ 0.98534209  0.96800772  0.69900366 ...,  0.99962235  0.95368603
#    0.99973985]
#  ...,
#  [ 0.98676524  0.96940432  0.70026855 ...,  0.99968661  0.96285663
#    0.99981183]
#  [ 0.98676524  0.96940432  0.70026855 ...,  0.99968661  0.96285663
#    0.99981183]
#  [ 0.98676524  0.96940432  0.70026855 ...,  0.99968661  0.96285663
#    0.99981183]]
# 60
# 11163
# Done Writing
# Error on iteration  401 :  3522129.51397
# Error on iteration  402 :  3481849.62092
# Error on iteration  403 :  3441590.45985
# Error on iteration  404 :  3401361.10542
# Error on iteration  405 :  3361165.71231
# Error on iteration  406 :  3321008.56794
# Error on iteration  407 :  3280894.07356
# Error on iteration  408 :  3240826.72366
# Error on iteration  409 :  3200811.08513
# Error on iteration  410 :  3160851.77595
# Error on iteration  411 :  3120953.44413
# Error on iteration  412 :  3081120.74809
# Error on iteration  413 :  3041358.33914
# Error on iteration  414 :  3001670.8473
# Error on iteration  415 :  2962062.87104
# Error on iteration  416 :  2922538.9717
# Error on iteration  417 :  2883103.67278
# Error on iteration  418 :  2843761.56266
# Error on iteration  419 :  2804517.3144
# Error on iteration  420 :  2765375.45352
# Error on iteration  421 :  2726340.38209
# Error on iteration  422 :  2687417.01683
# Error on iteration  423 :  2648612.01929
# Error on iteration  424 :  2609930.80656
# Error on iteration  425 :  2571377.75962
# Error on iteration  426 :  2532957.36178
# Error on iteration  427 :  2494674.28896
# Error on iteration  428 :  2456533.3963
# Error on iteration  429 :  2418539.70359
# Error on iteration  430 :  2380698.37748
# Error on iteration  431 :  2343014.90184
# Error on iteration  432 :  2305495.69122
# Error on iteration  433 :  2268148.26417
# Error on iteration  434 :  2230978.52959
# Error on iteration  435 :  2193990.93768
# Error on iteration  436 :  2157189.17853
# Error on iteration  437 :  2120576.07042
# Error on iteration  438 :  2084153.58932
# Error on iteration  439 :  2047922.51013
# Error on iteration  440 :  2011885.95273
# Error on iteration  441 :  1976051.7051
# Error on iteration  442 :  1940420.33204
# Error on iteration  443 :  1904988.82754
# Error on iteration  444 :  1869760.14761
# Error on iteration  445 :  1834734.14191
# Error on iteration  446 :  1799915.70472
# Error on iteration  447 :  1765310.52681
# Error on iteration  448 :  1730922.25507
# Error on iteration  449 :  1696744.88451
# Error on iteration  450 :  1662703.96456
# Error on iteration  451 :  1628883.09683
# Error on iteration  452 :  1595295.43476
# Error on iteration  453 :  1561962.73669
# Error on iteration  454 :  1528906.19604
# Error on iteration  455 :  1496141.01716
# Error on iteration  456 :  1463968.08185
# Error on iteration  457 :  1432242.52487
# Error on iteration  458 :  1400869.66366
# Error on iteration  459 :  1369834.30436
# Error on iteration  460 :  1339142.54294
# Error on iteration  461 :  1308764.57793
# Error on iteration  462 :  1278715.2253
# Error on iteration  463 :  1249001.02067
# Error on iteration  464 :  1219594.45411
# Error on iteration  465 :  1190510.39336
# Error on iteration  466 :  1161769.54518
# Error on iteration  467 :  1133336.9566
# Error on iteration  468 :  1105218.54935
# Error on iteration  469 :  1077434.17772
# Error on iteration  470 :  1049960.56792
# Error on iteration  471 :  1022821.97395
# Error on iteration  472 :  996024.933213
# Error on iteration  473 :  969549.030545
# Error on iteration  474 :  943410.839295
# Error on iteration  475 :  917617.712085
# Error on iteration  476 :  892174.956599
# Error on iteration  477 :  867097.214176
# Error on iteration  478 :  842360.399481
# Error on iteration  479 :  817985.510425
# Error on iteration  480 :  793979.200254
# Error on iteration  481 :  770330.147685
# Error on iteration  482 :  747046.280627
# Error on iteration  483 :  724144.790775
# Error on iteration  484 :  701536.617612
# Error on iteration  485 :  679381.041587
# Error on iteration  486 :  657597.596123
# Error on iteration  487 :  636201.459825
# Error on iteration  488 :  615154.800975
# Error on iteration  489 :  594536.733195
# Error on iteration  490 :  574244.904559
# Error on iteration  491 :  554399.921902
# Error on iteration  492 :  534907.934381
# Error on iteration  493 :  515742.187319
# Error on iteration  494 :  496953.092758
# Error on iteration  495 :  478565.597486
# Error on iteration  496 :  460387.697826
# Error on iteration  497 :  442764.21861
# Error on iteration  498 :  425451.229585
# Error on iteration  499 :  408592.042874
# Error on iteration  500 :  392023.690286
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.4034781   0.1960826   0.05809849 ...,  0.8303015   0.22781693
#    0.88300227]
#  [ 0.37066101  0.22030584  0.03560746 ...,  0.87643959  0.07562841
#    0.88644094]
#  ...,
#  [ 0.38366895  0.17283797  0.0371399  ...,  0.82136354  0.1188236
#    0.91951343]
#  [ 0.35022506  0.19299298  0.04434437 ...,  0.83593621  0.07812078
#    0.88045551]
#  [ 0.38366895  0.17283797  0.0371399  ...,  0.82136354  0.1188236
#    0.91951343]]
# 60
# 11163
# Done Writing
# Error on iteration  501 :  375872.56964
# Error on iteration  502 :  360121.644004
# Error on iteration  503 :  344673.587685
# Error on iteration  504 :  329589.479977
# Error on iteration  505 :  314984.711233
# Error on iteration  506 :  300602.29274
# Error on iteration  507 :  286597.925816
# Error on iteration  508 :  273067.693217
# Error on iteration  509 :  259787.058842
# Error on iteration  510 :  246721.202313
# Error on iteration  511 :  234198.419838
# Error on iteration  512 :  221925.341964
# Error on iteration  513 :  210034.187251
# Error on iteration  514 :  198429.514839
# Error on iteration  515 :  187064.24627
# Error on iteration  516 :  176175.313043
# Error on iteration  517 :  165463.867784
# Error on iteration  518 :  155345.407342
# Error on iteration  519 :  145470.58655
# Error on iteration  520 :  135945.904021
# Error on iteration  521 :  126688.062414
# Error on iteration  522 :  117871.756102
# Error on iteration  523 :  109326.620063
# Error on iteration  524 :  101133.73488
# Error on iteration  525 :  93002.9442028
# Error on iteration  526 :  85157.0539645
# Error on iteration  527 :  77806.0403406
# Error on iteration  528 :  70896.4756046
# Error on iteration  529 :  64116.5369877
# Error on iteration  530 :  57562.6502651
# Error on iteration  531 :  51407.4722074
# Error on iteration  532 :  45528.4085263
# Error on iteration  533 :  39881.2769142
# Error on iteration  534 :  34451.4002307
# Error on iteration  535 :  29315.6870721
# Error on iteration  536 :  24844.0950598
# Error on iteration  537 :  21112.7253375
# Error on iteration  538 :  19325.5203351
# Error on iteration  539 :  17284.2256285
# Error on iteration  540 :  14924.1669015
# Error on iteration  541 :  12316.6311342
# Error on iteration  542 :  9602.16267383
# Error on iteration  543 :  6906.13639551
# Error on iteration  544 :  4224.29074322
# Error on iteration  545 :  1591.36517659
# Error on iteration  546 :  -965.112665762
# Error on iteration  547 :  -3423.29843658
# Error on iteration  548 :  -5772.06559784
# Error on iteration  549 :  -8004.56701969
# Error on iteration  550 :  -10116.4246456
# Error on iteration  551 :  -12104.9422472
# Error on iteration  552 :  -13968.6347045
# Error on iteration  553 :  -15707.0572367
# Error on iteration  554 :  -17320.7837365
# Error on iteration  555 :  -18811.5533183
# Error on iteration  556 :  -20182.8518442
# Error on iteration  557 :  -21438.6967147
# Error on iteration  558 :  -22582.8096306
# Error on iteration  559 :  -23618.9209815
# Error on iteration  560 :  -24550.8299052
# Error on iteration  561 :  -25381.8467258
# Error on iteration  562 :  -26114.8651295
# Error on iteration  563 :  -26753.2112171
# Error on iteration  564 :  -27299.9009144
# Error on iteration  565 :  -27757.2118212
# Error on iteration  566 :  -28127.6277434
# Error on iteration  567 :  -28413.7762212
# Error on iteration  568 :  -28618.143233
# Error on iteration  569 :  -28743.1395168
# Error on iteration  570 :  -28791.4907336
# Error on iteration  571 :  -28766.1488323
# Error on iteration  572 :  -28670.2407358
# Error on iteration  573 :  -28506.9526592
# Error on iteration  574 :  -28279.4002996
# Error on iteration  575 :  -27990.5848346
# Error on iteration  576 :  -27643.3889571
# Error on iteration  577 :  -27240.5837272
# Error on iteration  578 :  -26784.8420936
# Error on iteration  579 :  -26278.7561019
# Error on iteration  580 :  -25724.8543283
# Error on iteration  581 :  -25125.6168275
# Error on iteration  582 :  -24483.4863222
# Error on iteration  583 :  -23800.8743385
# Error on iteration  584 :  -23080.1439937
# Error on iteration  585 :  -22323.5997054
# Error on iteration  586 :  -21533.4643164
# Error on iteration  587 :  -20711.9435062
# Error on iteration  588 :  -19861.4261206
# Error on iteration  589 :  -18984.2915473
# Error on iteration  590 :  -18082.8591901
# Error on iteration  591 :  -17159.3863197
# Error on iteration  592 :  -16216.0657582
# Error on iteration  593 :  -15255.0234799
# Error on iteration  594 :  -14278.3161138
# Error on iteration  595 :  -13287.9283985
# Error on iteration  596 :  -12285.7705706
# Error on iteration  597 :  -11273.6755129
# Error on iteration  598 :  -10253.3963891
# Error on iteration  599 :  -9226.60510385
# Error on iteration  600 :  -8194.89302378
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  2.94418335e-02   1.70290707e-02   3.33608596e-03 ...,   2.25284449e-01
#     1.61046324e-02   3.10257461e-01]
#  [  4.39385343e-03   8.39653083e-04   2.14290075e-04 ...,   1.47201421e-01
#     1.77399082e-03   1.42987112e-01]
#  ...,
#  [  3.84949207e-03   7.01300023e-04   1.71296631e-04 ...,   1.44162247e-01
#     1.60067350e-03   1.24298114e-01]
#  [  3.84949207e-03   7.01300023e-04   1.71296631e-04 ...,   1.44162247e-01
#     1.60067350e-03   1.24298114e-01]
#  [  3.84949207e-03   7.01300023e-04   1.71296631e-04 ...,   1.44162247e-01
#     1.60067350e-03   1.24298114e-01]]
# 60
# 11163
# Done Writing
# Error on iteration  601 :  -7163.40497733
# Error on iteration  602 :  -6122.67491973
# Error on iteration  603 :  -5085.04957659
# Error on iteration  604 :  -4048.24373047
# Error on iteration  605 :  -3013.61042082
# Error on iteration  606 :  -1982.49587397
# Error on iteration  607 :  -956.235341331
# Error on iteration  608 :  63.8585847685
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  2.83019314e-02   1.04807712e-02   2.50652953e-03 ...,   1.75922809e-01
#     1.76972934e-02   2.40270577e-01]
#  [  3.26781926e-03   6.49006973e-04   1.50045654e-04 ...,   1.16685996e-01
#     1.35515298e-03   1.11213130e-01]
#  ...,
#  [  2.88673813e-03   5.23157442e-04   1.26507890e-04 ...,   1.17274169e-01
#     1.16895966e-03   9.91444899e-02]
#  [  2.88673813e-03   5.23157442e-04   1.26507890e-04 ...,   1.17274169e-01
#     1.16895966e-03   9.91444899e-02]
#  [  2.88673813e-03   5.23157442e-04   1.26507890e-04 ...,   1.17274169e-01
#     1.16895966e-03   9.91444899e-02]]
# 60
# 11163
# Done Writing
# Error on iteration  609 :  1073.01328809
# Error on iteration  610 :  2080.46833011
# Error on iteration  611 :  3074.536598
# Error on iteration  612 :  3977.01271438
# Error on iteration  613 :  4868.69455355
# Error on iteration  614 :  5747.40131553
# Error on iteration  615 :  6611.49312885
# Error on iteration  616 :  7459.60758245
# Error on iteration  617 :  8290.54972873
# Error on iteration  618 :  9103.23735326
# Error on iteration  619 :  9896.67213315
# Error on iteration  620 :  10669.9230224
# Error on iteration  621 :  11422.1176339
# Error on iteration  622 :  12152.4379218
# Error on iteration  623 :  12860.1191519
# Error on iteration  624 :  13544.4511307
# Error on iteration  625 :  14204.7809166
# Error on iteration  626 :  14840.5156706
# Error on iteration  627 :  15451.123496
# Error on iteration  628 :  16036.129464
# Error on iteration  629 :  16595.1040668
# Error on iteration  630 :  17127.6446032
# Error on iteration  631 :  17633.3562059
# Error on iteration  632 :  18111.8438202
# Error on iteration  633 :  18562.72248
# Error on iteration  634 :  18985.642091
# Error on iteration  635 :  19380.3155976
# Error on iteration  636 :  19746.5417134
# Error on iteration  637 :  20084.2198208
# Error on iteration  638 :  20393.288836
# Error on iteration  639 :  20673.279036
# Error on iteration  640 :  20924.1542233
# Error on iteration  641 :  21146.3013745
# Error on iteration  642 :  21340.2399529
# Error on iteration  643 :  21506.587664
# Error on iteration  644 :  21646.0749295
# Error on iteration  645 :  21759.5323906
# Error on iteration  646 :  21847.8863734
# Error on iteration  647 :  21912.1353443
# Error on iteration  648 :  21953.3519139
# Error on iteration  649 :  21972.6679885
# Error on iteration  650 :  21971.2627139
# Error on iteration  651 :  21950.3419916
# Error on iteration  652 :  21911.12026
# Error on iteration  653 :  21854.8021394
# Error on iteration  654 :  21782.5638124
# Error on iteration  655 :  21695.5397946
# Error on iteration  656 :  21594.8141192
# Error on iteration  657 :  21481.4144159
# Error on iteration  658 :  21356.3301106
# Error on iteration  659 :  21220.530805
# Error on iteration  660 :  21074.905526
# Error on iteration  661 :  20920.2568013
# Error on iteration  662 :  20757.3417894
# Error on iteration  663 :  20586.8588487
# Error on iteration  664 :  20409.3867421
# Error on iteration  665 :  20225.496301
# Error on iteration  666 :  20035.8135714
# Error on iteration  667 :  19841.0232028
# Error on iteration  668 :  19641.8670978
# Error on iteration  669 :  19439.1277835
# Error on iteration  670 :  19233.6007044
# Error on iteration  671 :  19026.0450403
# Error on iteration  672 :  18817.135681
# Error on iteration  673 :  18607.4355523
# Error on iteration  674 :  18397.4392188
# Error on iteration  675 :  18187.6309324
# Error on iteration  676 :  17978.5256012
# Error on iteration  677 :  17771.0307833
# Error on iteration  678 :  17568.9367557
# Error on iteration  679 :  17374.0397774
# Error on iteration  680 :  17276.2825193
# Error on iteration  681 :  17072.9250868
# Error on iteration  682 :  18733.544882
# Error on iteration  683 :  17503.9623082
# Error on iteration  684 :  18923.1244615
# Error on iteration  685 :  17553.078905
# Error on iteration  686 :  19045.1386901
# Error on iteration  687 :  17576.5351172
# Error on iteration  688 :  19178.3069801
# Error on iteration  689 :  17586.282704
# Error on iteration  690 :  19326.5422993
# Error on iteration  691 :  17578.354709
# Error on iteration  692 :  19490.760724
# Error on iteration  693 :  17453.6494513
# Error on iteration  694 :  19603.6871336
# Error on iteration  695 :  17443.0394945
# Error on iteration  696 :  19777.0729959
# Error on iteration  697 :  17377.8062604
# Error on iteration  698 :  19890.5473948
# Error on iteration  699 :  17342.2626798
# Error on iteration  700 :  20006.8685575
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.65741134e-02   1.01895446e-02   1.62519544e-03 ...,   1.34232683e-01
#     7.34455550e-03   1.95667603e-01]
#  [  4.43509608e-03   1.07598257e-03   2.03294886e-04 ...,   5.46688797e-02
#     1.46964433e-03   7.95873864e-02]
#  ...,
#  [  5.66223087e-03   8.43399529e-04   1.95543808e-04 ...,   4.15656243e-02
#     1.81721829e-03   7.81708756e-02]
#  [  5.66223087e-03   8.43399529e-04   1.95543808e-04 ...,   4.15656243e-02
#     1.81721829e-03   7.81708756e-02]
#  [  5.66223087e-03   8.43399529e-04   1.95543808e-04 ...,   4.15656243e-02
#     1.81721829e-03   7.81708756e-02]]
# 60
# 11163
# Done Writing
# Error on iteration  701 :  17320.8508234
# Error on iteration  702 :  20031.7651146
# Error on iteration  703 :  17274.92086
# Error on iteration  704 :  20149.4057424
# Error on iteration  705 :  17270.5674783
# Error on iteration  706 :  20180.6512711
# Error on iteration  707 :  17333.0755551
# Error on iteration  708 :  20206.0662933
# Error on iteration  709 :  17331.4712048
# Error on iteration  710 :  20201.829698
# Error on iteration  711 :  17429.589846
# Error on iteration  712 :  20246.3082995
# Error on iteration  713 :  17497.1036918
# Error on iteration  714 :  20309.0510501
# Error on iteration  715 :  17467.4755616
# Error on iteration  716 :  20321.956214
# Error on iteration  717 :  17469.9260724
# Error on iteration  718 :  20316.9466377
# Error on iteration  719 :  17492.6008903
# Error on iteration  720 :  20318.8256681
# Error on iteration  721 :  17528.3106617
# Error on iteration  722 :  20338.0553825
# Error on iteration  723 :  17517.2100252
# Error on iteration  724 :  20344.3238004
# Error on iteration  725 :  17518.3112026
# Error on iteration  726 :  20343.4338117
# Error on iteration  727 :  17522.2675755
# Error on iteration  728 :  20341.8250296
# Error on iteration  729 :  17525.5792456
# Error on iteration  730 :  20341.1841141
# Error on iteration  731 :  17527.8297365
# Error on iteration  732 :  20341.3192544
# Error on iteration  733 :  17529.4309138
# Error on iteration  734 :  20341.749298
# Error on iteration  735 :  17530.7415728
# Error on iteration  736 :  20342.196925
# Error on iteration  737 :  17531.9130169
# Error on iteration  738 :  20342.5459938
# Error on iteration  739 :  17532.9758932
# Error on iteration  740 :  20342.7580116
# Error on iteration  741 :  17533.9232114
# Error on iteration  742 :  20342.8335811
# Error on iteration  743 :  17534.73167
# Error on iteration  744 :  20342.7895842
# Error on iteration  745 :  17535.3572114
# Error on iteration  746 :  20342.4349098
# Error on iteration  747 :  17535.7647775
# Error on iteration  748 :  20341.7075362
# Error on iteration  749 :  17535.8778196
# Error on iteration  750 :  20340.7903997
# Error on iteration  751 :  17535.6871491
# Error on iteration  752 :  20340.6956334
# Error on iteration  753 :  17535.2132741
# Error on iteration  754 :  20245.0348858
# Error on iteration  755 :  17591.6427257
# Error on iteration  756 :  20241.7065436
# Error on iteration  757 :  17573.2960145
# Error on iteration  758 :  18709.0693713
# Error on iteration  759 :  19563.7084848
# Error on iteration  760 :  17668.7504476
# Error on iteration  761 :  20354.4582518
# Error on iteration  762 :  17196.6991152
# Error on iteration  763 :  20548.3467479
# Error on iteration  764 :  17243.5466586
# Error on iteration  765 :  20405.5011332
# Error on iteration  766 :  17385.6134666
# Error on iteration  767 :  20299.723442
# Error on iteration  768 :  17447.7546704
# Error on iteration  769 :  20268.6331274
# Error on iteration  770 :  17460.2401
# Error on iteration  771 :  20268.2830543
# Error on iteration  772 :  17457.8203791
# Error on iteration  773 :  20273.9039429
# Error on iteration  774 :  17454.6420583
# Error on iteration  775 :  20277.6760158
# Error on iteration  776 :  17453.720415
# Error on iteration  777 :  20278.9486875
# Error on iteration  778 :  17454.3543121
# Error on iteration  779 :  20278.8069187
# Error on iteration  780 :  17455.4566726
# Error on iteration  781 :  20278.0833579
# Error on iteration  782 :  17456.4250364
# Error on iteration  783 :  20277.0953468
# Error on iteration  784 :  17457.0476104
# Error on iteration  785 :  20275.860697
# Error on iteration  786 :  17457.2836661
# Error on iteration  787 :  20274.2967593
# Error on iteration  788 :  17457.1342491
# Error on iteration  789 :  20272.2849946
# Error on iteration  790 :  17456.5729993
# Error on iteration  791 :  20162.452905
# Error on iteration  792 :  17415.1761231
# Error on iteration  793 :  20108.1104272
# Error on iteration  794 :  17341.6707848
# Error on iteration  795 :  20174.7441917
# Error on iteration  796 :  17316.4324062
# Error on iteration  797 :  20181.1593579
# Error on iteration  798 :  17323.8113148
# Error on iteration  799 :  20171.3405265
# Error on iteration  800 :  17334.6504798
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.01163241  0.00875465  0.00156343 ...,  0.12500493  0.00498971
#    0.14724174]
#  [ 0.00392053  0.00088406  0.00019362 ...,  0.0443971   0.00151978
#    0.06988882]
#  ...,
#  [ 0.00517609  0.00077374  0.00018682 ...,  0.03708382  0.00183778
#    0.07049103]
#  [ 0.00517609  0.00077374  0.00018682 ...,  0.03708382  0.00183778
#    0.07049103]
#  [ 0.00517609  0.00077374  0.00018682 ...,  0.03708382  0.00183778
#    0.07049103]]
# 60
# 11163
# Done Writing
# Error on iteration  801 :  20158.677719
# Error on iteration  802 :  17344.039515
# Error on iteration  803 :  20158.0739643
# Error on iteration  804 :  17343.4152186
# Error on iteration  805 :  20157.7090593
# Error on iteration  806 :  17469.8798866
# Error on iteration  807 :  20133.7490236
# Error on iteration  808 :  17366.7292138
# Error on iteration  809 :  20196.1897981
# Error on iteration  810 :  17456.1219583
# Error on iteration  811 :  20224.8961413
# Error on iteration  812 :  17384.0037015
# Error on iteration  813 :  20145.6722563
# Error on iteration  814 :  17331.9840517
# Error on iteration  815 :  20192.4104242
# Error on iteration  816 :  17443.4564222
# Error on iteration  817 :  20123.0250362
# Error on iteration  818 :  17337.1455199
# Error on iteration  819 :  20199.469268
# Error on iteration  820 :  17435.9321586
# Error on iteration  821 :  20134.5136108
# Error on iteration  822 :  17455.0687032
# Error on iteration  823 :  20262.8284701
# Error on iteration  824 :  17492.8695228
# Error on iteration  825 :  18658.5889872
# Error on iteration  826 :  19526.2554277
# Error on iteration  827 :  17507.3815741
# Error on iteration  828 :  20274.6370463
# Error on iteration  829 :  17126.2768837
# Error on iteration  830 :  20446.795848
# Error on iteration  831 :  17162.0738398
# Error on iteration  832 :  20319.4382808
# Error on iteration  833 :  17409.2121176
# Error on iteration  834 :  20264.9422632
# Error on iteration  835 :  17418.048186
# Error on iteration  836 :  20270.3648735
# Error on iteration  837 :  17482.338602
# Error on iteration  838 :  20293.3152572
# Error on iteration  839 :  17483.2465963
# Error on iteration  840 :  20320.7478194
# Error on iteration  841 :  17466.7178752
# Error on iteration  842 :  20328.2940738
# Error on iteration  843 :  17486.3623654
# Error on iteration  844 :  20327.5559927
# Error on iteration  845 :  17512.7649663
# Error on iteration  846 :  20334.9962503
# Error on iteration  847 :  17545.9594498
# Error on iteration  848 :  20354.2114709
# Error on iteration  849 :  17560.6287854
# Error on iteration  850 :  20378.815211
# Error on iteration  851 :  17545.6271912
# Error on iteration  852 :  20392.2257022
# Error on iteration  853 :  17538.6219417
# Error on iteration  854 :  20389.2864986
# Error on iteration  855 :  17547.0111436
# Error on iteration  856 :  20381.0186123
# Error on iteration  857 :  17650.6644875
# Error on iteration  858 :  20401.2861431
# Error on iteration  859 :  17585.3399091
# Error on iteration  860 :  20433.2381702
# Error on iteration  861 :  17645.8527643
# Error on iteration  862 :  20444.571757
# Error on iteration  863 :  17605.8410032
# Error on iteration  864 :  20459.7572608
# Error on iteration  865 :  17654.3818876
# Error on iteration  866 :  20460.8728973
# Error on iteration  867 :  17633.6085324
# Error on iteration  868 :  20470.4781214
# Error on iteration  869 :  17636.6343661
# Error on iteration  870 :  20466.8736292
# Error on iteration  871 :  17645.2226932
# Error on iteration  872 :  20462.7479346
# Error on iteration  873 :  17644.1983994
# Error on iteration  874 :  20460.3288238
# Error on iteration  875 :  17732.2357639
# Error on iteration  876 :  20468.8341236
# Error on iteration  877 :  17679.122053
# Error on iteration  878 :  20502.2471887
# Error on iteration  879 :  17659.037252
# Error on iteration  880 :  20503.6791997
# Error on iteration  881 :  17665.1789145
# Error on iteration  882 :  20492.7121725
# Error on iteration  883 :  17673.1217706
# Error on iteration  884 :  20483.6541579
# Error on iteration  885 :  17676.8774402
# Error on iteration  886 :  20477.9065309
# Error on iteration  887 :  17677.3747996
# Error on iteration  888 :  20473.6283539
# Error on iteration  889 :  17676.2437979
# Error on iteration  890 :  20469.3043816
# Error on iteration  891 :  17674.4320674
# Error on iteration  892 :  20464.2164477
# Error on iteration  893 :  17816.9176873
# Error on iteration  894 :  20466.35151
# Error on iteration  895 :  17693.1217307
# Error on iteration  896 :  20504.4955428
# Error on iteration  897 :  17699.5161848
# Error on iteration  898 :  20515.8171519
# Error on iteration  899 :  17738.7397498
# Error on iteration  900 :  20511.3990311
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.01221855  0.00698878  0.00134927 ...,  0.10710431  0.00660856
#    0.15654492]
#  [ 0.00424845  0.00085026  0.00026487 ...,  0.04088815  0.0018791
#    0.06539206]
#  ...,
#  [ 0.00542438  0.00081347  0.00021411 ...,  0.03616355  0.00217967
#    0.0703903 ]
#  [ 0.00542438  0.00081347  0.00021411 ...,  0.03616355  0.00217967
#    0.0703903 ]
#  [ 0.00542438  0.00081347  0.00021411 ...,  0.03616355  0.00217967
#    0.0703903 ]]
# 60
# 11163
# Done Writing
# Error on iteration  901 :  17730.8218949
# Error on iteration  902 :  20526.9806052
# Error on iteration  903 :  17917.7026096
# Error on iteration  904 :  20549.2636911
# Error on iteration  905 :  17893.691438
# Error on iteration  906 :  20641.3103439
# Error on iteration  907 :  17832.5774285
# Error on iteration  908 :  20698.4273233
# Error on iteration  909 :  17794.5392362
# Error on iteration  910 :  20705.4577331
# Error on iteration  911 :  17800.0662734
# Error on iteration  912 :  20684.8531217
# Error on iteration  913 :  17867.7157247
# Error on iteration  914 :  20663.380379
# Error on iteration  915 :  17889.5541687
# Error on iteration  916 :  20671.7276072
# Error on iteration  917 :  17942.4915195
# Error on iteration  918 :  20683.3507289
# Error on iteration  919 :  17858.9080493
# Error on iteration  920 :  20723.6735406
# Error on iteration  921 :  17899.2204582
# Error on iteration  922 :  20712.7721691
# Error on iteration  923 :  17934.6455943
# Error on iteration  924 :  20716.1880084
# Error on iteration  925 :  17931.6717672
# Error on iteration  926 :  20735.3044713
# Error on iteration  927 :  18039.7858142
# Error on iteration  928 :  20731.1554025
# Error on iteration  929 :  17902.6902779
# Error on iteration  930 :  20798.9887367
# Error on iteration  931 :  17893.4659942
# Error on iteration  932 :  20789.1097353
# Error on iteration  933 :  17917.1962866
# Error on iteration  934 :  20770.9271899
# Error on iteration  935 :  17934.9441227
# Error on iteration  936 :  20762.6687445
# Error on iteration  937 :  17942.9294617
# Error on iteration  938 :  20761.8336384
# Error on iteration  939 :  17945.6601426
# Error on iteration  940 :  20763.7034334
# Error on iteration  941 :  17946.7090175
# Error on iteration  942 :  20766.0004563
# Error on iteration  943 :  18074.2942212
# Error on iteration  944 :  20746.5787755
# Error on iteration  945 :  17952.685281
# Error on iteration  946 :  20811.6200124
# Error on iteration  947 :  17935.0005112
# Error on iteration  948 :  20811.058953
# Error on iteration  949 :  17948.4285236
# Error on iteration  950 :  20798.652747
# Error on iteration  951 :  17960.7399416
# Error on iteration  952 :  20791.5985718
# Error on iteration  953 :  17966.3455753
# Error on iteration  954 :  20789.3708493
# Error on iteration  955 :  17967.7425326
# Error on iteration  956 :  20789.8115019
# Error on iteration  957 :  17967.229577
# Error on iteration  958 :  20790.0210736
# Error on iteration  959 :  17966.409405
# Error on iteration  960 :  20787.623177
# Error on iteration  961 :  17965.5338599
# Error on iteration  962 :  20787.5383241
# Error on iteration  963 :  17963.248322
# Error on iteration  964 :  20786.1846259
# Error on iteration  965 :  17961.0167331
# Error on iteration  966 :  19261.1655711
# Error on iteration  967 :  18470.9899841
# Error on iteration  968 :  20207.1785851
# Error on iteration  969 :  17884.9203464
# Error on iteration  970 :  20595.6263761
# Error on iteration  971 :  17666.887966
# Error on iteration  972 :  20666.0796301
# Error on iteration  973 :  17685.3253481
# Error on iteration  974 :  20590.3185241
# Error on iteration  975 :  17749.2241111
# Error on iteration  976 :  20464.6412071
# Error on iteration  977 :  17791.1459298
# Error on iteration  978 :  20486.3506528
# Error on iteration  979 :  17764.5276037
# Error on iteration  980 :  20479.5520579
# Error on iteration  981 :  17785.5116522
# Error on iteration  982 :  20455.8506755
# Error on iteration  983 :  17744.3427908
# Error on iteration  984 :  20448.1991822
# Error on iteration  985 :  17825.8883107
# Error on iteration  986 :  20398.1142362
# Error on iteration  987 :  17727.788624
# Error on iteration  988 :  20433.4223597
# Error on iteration  989 :  17731.6790594
# Error on iteration  990 :  20462.4235966
# Error on iteration  991 :  17672.1810471
# Error on iteration  992 :  20463.3996804
# Error on iteration  993 :  17671.2534666
# Error on iteration  994 :  20430.8575049
# Error on iteration  995 :  17932.1346554
# Error on iteration  996 :  20390.49868
# Error on iteration  997 :  17699.4608458
# Error on iteration  998 :  20508.9153162
# Error on iteration  999 :  17645.048942
# Error on iteration  1000 :  20494.6903669
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.0091546   0.0045034   0.00091298 ...,  0.09387899  0.00548363
#    0.12947208]
#  [ 0.00427891  0.00087934  0.00025113 ...,  0.03794021  0.00187333
#    0.05569973]
#  ...,
#  [ 0.00546195  0.00081763  0.00023823 ...,  0.03049253  0.00271776
#    0.05708405]
#  [ 0.00546195  0.00081763  0.00023823 ...,  0.03049253  0.00271776
#    0.05708405]
#  [ 0.00546195  0.00081763  0.00023823 ...,  0.03049253  0.00271776
#    0.05708405]]
# 60
# 11163
# Done Writing
# Error on iteration  1001 :  17658.7118878
# Error on iteration  1002 :  20451.9205073
# Error on iteration  1003 :  17747.0498399
# Error on iteration  1004 :  20410.3322001
# Error on iteration  1005 :  18756.5801528
# Error on iteration  1006 :  18649.7835666
# Error on iteration  1007 :  18620.8542311
# Error on iteration  1008 :  19973.3394055
# Error on iteration  1009 :  17598.5724545
# Error on iteration  1010 :  20751.2337736
# Error on iteration  1011 :  17208.1497796
# Error on iteration  1012 :  19341.5584621
# Error on iteration  1013 :  17916.1978016
# Error on iteration  1014 :  20043.1157364
# Error on iteration  1015 :  18791.5641522
# ...
# Error on iteration  1807 :  19459.4802646
# Error on iteration  1808 :  15971.3704881
# Error on iteration  1809 :  19043.2612909
# Error on iteration  1810 :  16081.0025874
# Error on iteration  1811 :  18957.0829427
# Error on iteration  1812 :  17769.6213208
# Error on iteration  1813 :  16690.2033231
# Error on iteration  1814 :  17169.2654403
# Error on iteration  1815 :  18548.7360379
# Error on iteration  1816 :  16054.2454569
# Error on iteration  1817 :  19325.0791464
# Error on iteration  1818 :  17389.3155457
# Error on iteration  1819 :  16966.3393086
# Error on iteration  1820 :  17131.1931892
# Error on iteration  1821 :  18623.6959662
# Error on iteration  1822 :  17551.7942551
# Error on iteration  1823 :  16902.8573791
# Error on iteration  1824 :  17383.4337568
# Error on iteration  1825 :  18486.5041687
# Error on iteration  1826 :  17444.9968254
# Error on iteration  1827 :  17041.145357
# Error on iteration  1828 :  19126.0125704
# Error on iteration  1829 :  15056.2244308
# Error on iteration  1830 :  20326.2406307
# Error on iteration  1831 :  15548.8108998
# Error on iteration  1832 :  19309.4308725
# Error on iteration  1833 :  16148.1718121
# Error on iteration  1834 :  19052.1584329
# Error on iteration  1835 :  16227.222153
# Error on iteration  1836 :  17302.1529385
# Error on iteration  1837 :  18494.576778
# Error on iteration  1838 :  16216.3945409
# Error on iteration  1839 :  19125.5846649
# Error on iteration  1840 :  15867.2056439
# Error on iteration  1841 :  19205.079378
# Error on iteration  1842 :  17664.1592819
# Error on iteration  1843 :  16747.0408022
# Error on iteration  1844 :  17169.2542213
# Error on iteration  1845 :  18565.8918927
# Error on iteration  1846 :  17683.3800519
# Error on iteration  1847 :  16691.2397762
# Error on iteration  1848 :  17426.4436402
# Error on iteration  1849 :  18427.9970307
# Error on iteration  1850 :  17547.4721383
# Error on iteration  1851 :  16792.9715077
# Error on iteration  1852 :  17525.0905291
# Error on iteration  1853 :  18275.1391596
# Error on iteration  1854 :  17415.3850957
# Error on iteration  1855 :  16949.6311038
# Error on iteration  1856 :  17416.4065402
# Error on iteration  1857 :  18216.1122465
# Error on iteration  1858 :  17032.7671877
# Error on iteration  1859 :  17475.6172501
# Error on iteration  1860 :  16470.7961465
# Error on iteration  1861 :  19834.0305917
# Error on iteration  1862 :  14083.729143
# Error on iteration  1863 :  19865.748001
# Error on iteration  1864 :  15665.6673101
# Error on iteration  1865 :  18751.7491571
# Error on iteration  1866 :  17692.8692838
# Error on iteration  1867 :  16379.7400763
# Error on iteration  1868 :  18604.9430849
# Error on iteration  1869 :  15820.2500955
# Error on iteration  1870 :  18842.5220103
# Error on iteration  1871 :  17406.4195935
# Error on iteration  1872 :  16477.8055876
# Error on iteration  1873 :  16903.0748071
# Error on iteration  1874 :  18209.3316337
# Error on iteration  1875 :  17329.7346859
# Error on iteration  1876 :  16390.7217796
# Error on iteration  1877 :  18754.1755776
# Error on iteration  1878 :  15327.9375434
# Error on iteration  1879 :  19358.1619145
# Error on iteration  1880 :  15397.0391772
# Error on iteration  1881 :  18959.7346222
# Error on iteration  1882 :  15771.0040051
# Error on iteration  1883 :  18713.9748566
# Error on iteration  1884 :  15888.0976237
# Error on iteration  1885 :  18674.3770955
# Error on iteration  1886 :  15889.9590919
# Error on iteration  1887 :  18690.4616243
# Error on iteration  1888 :  15869.6430573
# Error on iteration  1889 :  17203.4652117
# Error on iteration  1890 :  17957.0079995
# Error on iteration  1891 :  16023.3606405
# Error on iteration  1892 :  18739.0800796
# Error on iteration  1893 :  15552.0946019
# Error on iteration  1894 :  18945.6813319
# Error on iteration  1895 :  17113.5619618
# Error on iteration  1896 :  16519.6924994
# Error on iteration  1897 :  18418.9806806
# Error on iteration  1898 :  15700.7409679
# Error on iteration  1899 :  17474.1436456
# Error on iteration  1900 :  17661.2820934
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.0101257   0.00696659  0.0014338  ...,  0.10099089  0.0066733
#    0.12705071]
#  [ 0.00531082  0.00108199  0.00027335 ...,  0.03156429  0.00227681
#    0.04468768]
#  ...,
#  [ 0.00464783  0.00088643  0.00022499 ...,  0.02569161  0.00297685
#    0.03732112]
#  [ 0.00464783  0.00088643  0.00022499 ...,  0.02569161  0.00297685
#    0.03732112]
#  [ 0.00464783  0.00088643  0.00022499 ...,  0.02569161  0.00297685
#    0.03732112]]
# 60
# 11163
# Done Writing
# Error on iteration  1901 :  17564.4856241
# Error on iteration  1902 :  16048.9243161
# Error on iteration  1903 :  18924.4715463
# Error on iteration  1904 :  15113.2233414
# Error on iteration  1905 :  19258.6200716
# Error on iteration  1906 :  15407.141891
# Error on iteration  1907 :  18790.1026435
# Error on iteration  1908 :  15745.451194
# Error on iteration  1909 :  17107.9528508
# Error on iteration  1910 :  17847.925051
# Error on iteration  1911 :  17478.4491762
# Error on iteration  1912 :  16306.4189716
# Error on iteration  1913 :  18547.3832779
# Error on iteration  1914 :  15515.9023035
# Error on iteration  1915 :  19030.560827
# Error on iteration  1916 :  15433.2449764
# Error on iteration  1917 :  18869.9915984
# Error on iteration  1918 :  15665.2551269
# Error on iteration  1919 :  18678.2353433
# Error on iteration  1920 :  15782.1943819
# Error on iteration  1921 :  18620.8468096
# Error on iteration  1922 :  15804.0527467
# Error on iteration  1923 :  18624.7367183
# Error on iteration  1924 :  15795.8498212
# Error on iteration  1925 :  18641.4244923
# Error on iteration  1926 :  15787.2412716
# Error on iteration  1927 :  18653.3004992
# Error on iteration  1928 :  15784.7611791
# Error on iteration  1929 :  18659.5369969
# Error on iteration  1930 :  15786.6795812
# Error on iteration  1931 :  18662.6362611
# Error on iteration  1932 :  15789.5406017
# Error on iteration  1933 :  18664.9771937
# Error on iteration  1934 :  15792.7442729
# Error on iteration  1935 :  18667.7240072
# Error on iteration  1936 :  15796.6927383
# Error on iteration  1937 :  18671.1737659
# Error on iteration  1938 :  15799.7062661
# Error on iteration  1939 :  18674.6384837
# Error on iteration  1940 :  15803.5967691
# Error on iteration  1941 :  18678.0926971
# Error on iteration  1942 :  15808.1518119
# Error on iteration  1943 :  18683.8970513
# Error on iteration  1944 :  15811.8084934
# Error on iteration  1945 :  18688.4146236
# Error on iteration  1946 :  15817.4931612
# Error on iteration  1947 :  18695.8727639
# Error on iteration  1948 :  15820.6842073
# Error on iteration  1949 :  17242.9750132
# Error on iteration  1950 :  16377.1080875
# Error on iteration  1951 :  18324.7803485
# Error on iteration  1952 :  17179.8326203
# Error on iteration  1953 :  18014.8488071
# Error on iteration  1954 :  15959.5299153
# Error on iteration  1955 :  19026.4760887
# Error on iteration  1956 :  15337.220384
# Error on iteration  1957 :  19168.6601015
# Error on iteration  1958 :  15585.824192
# Error on iteration  1959 :  17392.0677113
# Error on iteration  1960 :  17828.5377705
# Error on iteration  1961 :  17642.2412915
# Error on iteration  1962 :  16337.7308818
# Error on iteration  1963 :  17263.9504739
# Error on iteration  1964 :  17896.4067133
# Error on iteration  1965 :  17441.9392743
# Error on iteration  1966 :  16470.5323117
# Error on iteration  1967 :  17427.4568083
# Error on iteration  1968 :  17718.8331772
# Error on iteration  1969 :  17524.6977504
# Error on iteration  1970 :  16338.3801244
# Error on iteration  1971 :  17806.0917208
# Error on iteration  1972 :  17126.9977196
# Error on iteration  1973 :  18289.1655341
# Error on iteration  1974 :  15140.0706684
# Error on iteration  1975 :  20381.7609774
# Error on iteration  1976 :  15016.2104476
# Error on iteration  1977 :  17611.7516851
# Error on iteration  1978 :  17875.0421169
# Error on iteration  1979 :  16253.4211636
# Error on iteration  1980 :  17100.8628787
# Error on iteration  1981 :  16479.9952503
# Error on iteration  1982 :  18461.9044104
# Error on iteration  1983 :  15520.9214249
# Error on iteration  1984 :  19068.8433089
# Error on iteration  1985 :  16974.6889035
# Error on iteration  1986 :  18259.6521775
# Error on iteration  1987 :  15762.6928075
# Error on iteration  1988 :  19012.9109022
# Error on iteration  1989 :  15417.6187454
# Error on iteration  1990 :  17463.5766608
# Error on iteration  1991 :  16143.2273576
# Error on iteration  1992 :  18530.2695957
# Error on iteration  1993 :  15461.0838205
# Error on iteration  1994 :  18903.3911197
# Error on iteration  1995 :  17017.8918701
# Error on iteration  1996 :  18123.1791695
# Error on iteration  1997 :  15901.7347436
# Error on iteration  1998 :  17372.0038683
# Error on iteration  1999 :  17795.3012592
# Error on iteration  2000 :  15947.7235924
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.01104081  0.00472446  0.00113187 ...,  0.10742557  0.00504346
#    0.10420748]
#  [ 0.00496141  0.00105892  0.00027514 ...,  0.02879693  0.00200381
#    0.04227678]
#  ...,
#  [ 0.00440713  0.00091685  0.00023243 ...,  0.02343957  0.00319716
#    0.03713825]
#  [ 0.00440713  0.00091685  0.00023243 ...,  0.02343957  0.00319716
#    0.03713825]
#  [ 0.00440713  0.00091685  0.00023243 ...,  0.02343957  0.00319716
#    0.03713825]]
# 60
# 11163
# Done Writing
# Error on iteration  2001 :  18973.058283
# Error on iteration  2002 :  15170.6197785
# Error on iteration  2003 :  19196.1919414
# Error on iteration  2004 :  17005.7893433
# Error on iteration  2005 :  16694.9285556
# Error on iteration  2006 :  18361.9499908
# Error on iteration  2007 :  15651.3464403
# Error on iteration  2008 :  17429.6274385
# Error on iteration  2009 :  16055.6855853
# Error on iteration  2010 :  18605.7349467
# Error on iteration  2011 :  15234.0535407
# Error on iteration  2012 :  19017.5640107
# Error on iteration  2013 :  15273.8409982
# Error on iteration  2014 :  18768.3869645
# Error on iteration  2015 :  17130.5813641
# Error on iteration  2016 :  17976.523228
# Error on iteration  2017 :  15986.6431483
# Error on iteration  2018 :  18737.6903204
# Error on iteration  2019 :  15513.9190037
# Error on iteration  2020 :  17378.375547
# Error on iteration  2021 :  17698.9403693
# Error on iteration  2022 :  17540.5277928
# Error on iteration  2023 :  16196.5193587
# Error on iteration  2024 :  18759.3308593
# Error on iteration  2025 :  15248.6508
# Error on iteration  2026 :  19207.4702975
# Error on iteration  2027 :  15354.6818628
# Error on iteration  2028 :  17330.8125197
# Error on iteration  2029 :  17722.9288403
# Error on iteration  2030 :  16016.2727419
# Error on iteration  2031 :  18588.0544449
# Error on iteration  2032 :  17004.8139624
# Error on iteration  2033 :  16640.6150203
# Error on iteration  2034 :  18329.4125443
# Error on iteration  2035 :  15520.733461
# Error on iteration  2036 :  17646.0045312
# Error on iteration  2037 :  15856.1358782
# Error on iteration  2038 :  18743.1195149
# Error on iteration  2039 :  15118.9457779
# Error on iteration  2040 :  19012.6390428
# Error on iteration  2041 :  16853.5987769
# Error on iteration  2042 :  18117.4656533
# Error on iteration  2043 :  15836.376791
# Error on iteration  2044 :  18799.0721517
# Error on iteration  2045 :  15418.5330766
# Error on iteration  2046 :  18890.3587295
# Error on iteration  2047 :  15513.5972625
# Error on iteration  2048 :  18716.7208115
# Error on iteration  2049 :  15664.2803389
# Error on iteration  2050 :  18608.6329095
# Error on iteration  2051 :  15723.1416095
# Error on iteration  2052 :  18586.4649836
# Error on iteration  2053 :  15732.3308917
# Error on iteration  2054 :  18586.7295511
# Error on iteration  2055 :  15723.4599425
# Error on iteration  2056 :  18593.7745493
# Error on iteration  2057 :  15713.9949571
# Error on iteration  2058 :  17098.3033673
# Error on iteration  2059 :  17772.9321902
# Error on iteration  2060 :  17434.229047
# Error on iteration  2061 :  17837.9211068
# Error on iteration  2062 :  15965.7728782
# Error on iteration  2063 :  17440.0595928
# Error on iteration  2064 :  16020.8595567
# Error on iteration  2065 :  17158.8140087
# Error on iteration  2066 :  17604.102935
# Error on iteration  2067 :  17227.4680421
# Error on iteration  2068 :  16177.4976691
# Error on iteration  2069 :  17293.9717861
# Error on iteration  2070 :  17381.5231202
# Error on iteration  2071 :  17366.2568098
# Error on iteration  2072 :  17508.2604223
# Error on iteration  2073 :  15853.7133812
# Error on iteration  2074 :  19773.7632006
# Error on iteration  2075 :  14191.1538998
# Error on iteration  2076 :  19395.8452553
# Error on iteration  2077 :  15546.9943565
# Error on iteration  2078 :  18513.8969693
# Error on iteration  2079 :  15778.7817263
# Error on iteration  2080 :  18400.3286548
# Error on iteration  2081 :  15804.1950704
# Error on iteration  2082 :  18437.791834
# Error on iteration  2083 :  15745.6225464
# Error on iteration  2084 :  18502.4766674
# Error on iteration  2085 :  15691.425531
# Error on iteration  2086 :  18546.5043179
# Error on iteration  2087 :  15661.8249494
# Error on iteration  2088 :  18559.1142993
# Error on iteration  2089 :  15656.9376378
# Error on iteration  2090 :  18559.8515991
# Error on iteration  2091 :  15659.2698339
# Error on iteration  2092 :  18557.0318139
# Error on iteration  2093 :  15661.9779077
# Error on iteration  2094 :  18554.5626396
# Error on iteration  2095 :  15664.7343835
# Error on iteration  2096 :  17050.1780666
# Error on iteration  2097 :  16172.2875791
# Error on iteration  2098 :  16634.9617244
# Error on iteration  2099 :  16204.1843373
# Error on iteration  2100 :  18038.6920204
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 0.00878065  0.00425686  0.00099711 ...,  0.08160182  0.0051825
#    0.13250784]
#  [ 0.00491618  0.00123115  0.00027986 ...,  0.02801377  0.00223161
#    0.04540019]
#  ...,
#  [ 0.0044915   0.00103024  0.0002479  ...,  0.02396618  0.00349361
#    0.0397684 ]
#  [ 0.0044915   0.00103024  0.0002479  ...,  0.02396618  0.00349361
#    0.0397684 ]
#  [ 0.0044915   0.00103024  0.0002479  ...,  0.02396618  0.00349361
#    0.0397684 ]]
# 60
# 11163
# Done Writing
# Error on iteration  2101 :  16762.9681419
# Error on iteration  2102 :  16267.7511421
# Error on iteration  2103 :  18225.7250487
# Error on iteration  2104 :  14952.8476419
# Error on iteration  2105 :  17520.4422511
# Error on iteration  2106 :  15421.4879933
# Error on iteration  2107 :  16911.8186329
# Error on iteration  2108 :  17295.1678828
# Error on iteration  2109 :  15391.8011335
# Error on iteration  2110 :  17004.4835705
# Error on iteration  2111 :  17109.3276576
# Error on iteration  2112 :  15359.7861613
# Error on iteration  2113 :  18718.3427221
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2c7dca737537> in <module>()
#      14     RNN.forwardProp()
#      15     #update all our weights using our error
# ---> 16     error = RNN.backProp()
#      17     #once our error/loss is small enough
#      18     print("Error on iteration ", i, ": ", error)
#
# <ipython-input-8-ab566380a819> in backProp(self)
#     103             #Finally, call the LSTM cell's backprop, retreive gradient updates
#     104             #gradient updates for forget, input, cell unit, and output gates + cell states & hiddens states
# --> 105             fu, iu, cu, ou, dfcs, dfhs = self.LSTM.backProp(error, self.ca[i-1], self.af[i], self.ai[i], self.ac[i], self.ao[i], dfcs, dfhs)
#     106             #calculate total error (not necesarry, used to measure training progress)
#     107             totalError += np.sum(error)
#
# <ipython-input-9-f3c535c6790d> in backProp(self, e, pcs, f, i, c, o, dfcs, dfhs)
#      90         #deriv hidden state = (deriv cell * cell) * output + deriv output * output * output deriv input * input * output + deriv forget
#      91         #* forget * output
# ---> 92         dphs = np.dot(dc, self.c)[:self.ys] + np.dot(do, self.o)[:self.ys] + np.dot(di, self.i)[:self.ys] + np.dot(df, self.f)[:self.ys]
#      93         #return update gradinets for forget, input, cell, output, cell state, hidden state
#      94         return fu, iu, cu, ou, dpcs, dphs
#
# KeyboardInterrupt:
